# %%
import pandas as pd
df = pd.read_csv("synthetic_shopping_data.csv")
df.shape
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   5000 non-null   int64
#  1   customer_gender      5000 non-null   object
#  2   customer_age         5000 non-null   int64
#  3   season               5000 non-null   object
#  4   category             5000 non-null   object
#  5   product              5000 non-null   object
#  6   actual_price         5000 non-null   float64
#  7   discount_applied     5000 non-null   float64
#  8   customer_sentiments  5000 non-null   object
#  9   previous_sales       5000 non-null   int64
#  10  Previous_sales       5000 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 429.8+ KB
